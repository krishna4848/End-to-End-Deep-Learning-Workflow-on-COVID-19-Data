# %% [markdown]
# ##  [ CM 2 ]
# __KEVAL PRAJAPATI (20908584, kbprajap@uwaterloo.ca)__

# %% [markdown]
# __I have decided to create 3 separate networks for each of the target label namely: Confirmed, Deaths and Recovered__

# %%
# AUTHOR: KEVAL PRAJAPATI 
# IMPORTING NECESSARY LIBRARIES
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Dense, Dropout, Flatten
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import confusion_matrix , classification_report
from tensorflow.keras.utils import to_categorical
from imblearn.pipeline import Pipeline
import time

# %%
#Importing the hybrid dataset
df = pd.read_csv('D:\COLLEGE\Waterloo\TERM 1\ECE 657A\Assigments\Assignment 3\Dataset\hybrid_dataset.csv')

# %%
df.head()
# Out:
#    Day  State ID       Lat     Long_    Active  Incident_Rate  \
# 0    2         1 -1.178670  0.304586 -0.200701       0.144028
# 1    2         2  3.608919 -3.033032 -0.449116      -0.290315
# 2    2         3 -0.946051 -0.945268  0.389194       0.088543
# 3    2         4 -0.741727  0.025825 -0.482520       0.202252
# 4    2         5 -0.552794 -1.365662  4.276989      -0.502599
#
#    Total_Test_Results  Case_Fatality_Ratio  Testing_Rate  \
# 0           -0.483568            -0.476902     -1.302217
# 1           -0.569578            -1.800519      2.071905
# 2           -0.007494             0.074416     -1.269412
# 3           -0.456622            -0.031311     -0.559356
# 4            4.023547            -0.792949     -0.177608
#
#    Resident Population 2020 Census  Population Density 2020 Census  \
# 0                        -0.128626                       -0.217091
# 1                        -0.754447                       -0.276853
# 2                         0.181627                       -0.239250
# 3                        -0.422184                       -0.242302
# 4                         4.905194                       -0.122779
#
#    Density Rank 2020 Census  SexRatio        PC1        PC2  Confirmed  \
# 0                  0.118788 -1.168679 -24.223517 -14.514321       True
# 1                  1.614954  3.492526 -23.151357 -14.474219       True
# 2                  0.509092  0.385056 -22.252978 -14.510294       True
# 3                  0.574143 -0.547185 -21.208164 -14.503685       True
# 4                 -0.922023  0.385056 -20.446867 -14.466792       True
#
#    Deaths  Recovered
# 0   False      False
# 1    True      False
# 2    True       True
# 3    True       True
# 4    True      False

# %% [markdown]
# __SPLITTING THE DATASET IN FEATURES AND LABELS__<br>
#  I have divided the labels into 3 different one labels namely: Confirmed, Deaths, and Recovered

# %%
X = df.iloc[:,:-3]
YC = df.iloc[:,-3]
YD = df.iloc[:,-2]
YR = df.iloc[:,-1]

# %% [markdown]
# __Checking the balance of the each of the target labels__

# %%
print('Confirmed label counts:\n',YC.value_counts())
print('Death label counts:\n',YD.value_counts())
print('Recovered label counts:\n',YR.value_counts())
# Out:
# Confirmed label counts:
#  True     1329
# False      51
# Name: Confirmed, dtype: int64
# Death label counts:
#  True     1244
# False     136
# Name: Deaths, dtype: int64
# Recovered label counts:
#  True     864
# False    516
# Name: Recovered, dtype: int64

# %% [markdown]
# __Balancing the target labels using data augmentation technique__<br>
#  Using oversampling method for minority class and undersampling for majority class

# %%
oversample = SMOTE()
undersample=RandomUnderSampler()
steps = [("o",oversample),("u",undersample)]
pipeline  = Pipeline(steps=steps)

# %%
XC_sm, YC_sm = pipeline.fit_resample(X, YC)
XD_sm, YD_sm = pipeline.fit_resample(X, YD)
XR_sm, YR_sm = pipeline.fit_resample(X, YR)

# %% [markdown]
# __One hot encoding for target labels since we are asked to use softmax activation function__

# %%
def OHE(Y):
    Y_OHE = to_categorical(Y, num_classes=2)
    return Y_OHE

YC_OHE = OHE(YC_sm)
YD_OHE = OHE(YD_sm)
YR_OHE = OHE(YR_sm)

# %% [markdown]
# __Defining the model__

# %%
# Splitting the dataset into train, test and validate sets
def split_data(X,Y):
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=15,stratify = Y)
    X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = 0.2, random_state=15,stratify = Y_train)
    return X_train, X_test, Y_train, Y_test, X_val, Y_val

# Defining the deep neural network 
def DNN(X,Y):
   # Splitting the dataset  
    X_train, X_test, Y_train, Y_test, X_val, Y_val = split_data(X,Y)
   # The model itself
    NN = models.Sequential([
        
        # Layer 1 with 20 nodes and ReLU activation function
        layers.Dense(20, activation='relu'),
        
        # Layer 2 with 20 nodes and ReLU activation function
        layers.Dense(20, activation='relu'),
        
        #Output layer with 2 nodes and Softmax activation function
        layers.Dense(2, activation='softmax')    
    ])
    
    #Training 
    start_tr = time.process_time()
    NN.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
    NN_scores=NN.fit(X_train, Y_train,validation_data =(X_val,Y_val), epochs=50)
    end_tr = time.process_time() - start_tr
    print('\n Training Time:',end_tr)
    
    #Testing 
    start_te = time.process_time()
    test_score = NN.evaluate(X_test, Y_test)
    end_te = time.process_time() - start_te
    
    # Testing Loss and Accuracy
    print('\n Testing time:',end_te)
    print('Test loss:',test_score[0])
    print('Test accuracy: ',test_score[1])
    
    Y_pred_c = NN.predict_classes(X_test)
    Y_test_no=np.argmax(Y_test,axis=1)
    print('Classification_report:\n',classification_report(Y_test_no,Y_pred_c))
    
    #plot for accuracy vs epochs
    plt.plot(NN_scores.history['accuracy'])
    plt.plot(NN_scores.history['val_accuracy'])
    plt.title('Accuracy vs Training Epochs')
    plt.ylabel('Accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()
    
    #plot for loss vs epochs
    plt.plot(NN_scores.history['loss'])
    plt.plot(NN_scores.history['val_loss'])
    plt.title('Training Loss vs Training Epochs')
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %% [markdown]
# ### A) Training and testing the model for balanced dataset

# %% [markdown]
# __i) Neural network 1 for Confirmed label__

# %%
# Neural Network 1 for Confirmed label
DNN(XC_sm,YC_OHE)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Layer dense_9 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 54/54 [==============================] - 0s 3ms/step - loss: 1.6875 - accuracy: 0.5429 - val_loss: 0.7582 - val_accuracy: 0.5610
# Epoch 2/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.6640 - accuracy: 0.5871 - val_loss: 0.6169 - val_accuracy: 0.6573
# Epoch 3/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.5963 - accuracy: 0.6906 - val_loss: 0.5915 - val_accuracy: 0.6901
# Epoch 4/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.5584 - accuracy: 0.7265 - val_loss: 0.5558 - val_accuracy: 0.6808
# Epoch 5/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.5368 - accuracy: 0.7282 - val_loss: 0.5210 - val_accuracy: 0.7723
# Epoch 6/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.5137 - accuracy: 0.7629 - val_loss: 0.4840 - val_accuracy: 0.7793
# Epoch 7/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.4886 - accuracy: 0.7829 - val_loss: 0.4644 - val_accuracy: 0.7864
# Epoch 8/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.4736 - accuracy: 0.7918 - val_loss: 0.4543 - val_accuracy: 0.7887
# Epoch 9/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.4590 - accuracy: 0.7959 - val_loss: 0.4424 - val_accuracy: 0.7958
# Epoch 10/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.4539 - accuracy: 0.7876 - val_loss: 0.4222 - val_accuracy: 0.8099
# Epoch 11/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.4369 - accuracy: 0.7953 - val_loss: 0.4178 - val_accuracy: 0.8028
# Epoch 12/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.4312 - accuracy: 0.8076 - val_loss: 0.3992 - val_accuracy: 0.8404
# Epoch 13/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.4173 - accuracy: 0.8129 - val_loss: 0.4120 - val_accuracy: 0.8075
# Epoch 14/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.4063 - accuracy: 0.8194 - val_loss: 0.3961 - val_accuracy: 0.8216
# Epoch 15/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3977 - accuracy: 0.8276 - val_loss: 0.3707 - val_accuracy: 0.8662
# Epoch 16/50
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3876 - accuracy: 0.8371 - val_loss: 0.3718 - val_accuracy: 0.8521
# Epoch 17/50
# 54/54 [==============================] - 0s 2ms/step - loss: 0.3801 - accuracy: 0.8406 - val_loss: 0.3724 - val_accuracy: 0.8333
# Epoch 18/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3837 - accuracy: 0.8365 - val_loss: 0.3638 - val_accuracy: 0.8474
# Epoch 19/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3705 - accuracy: 0.8453 - val_loss: 0.3586 - val_accuracy: 0.8404
# Epoch 20/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3658 - accuracy: 0.8494 - val_loss: 0.3445 - val_accuracy: 0.8662
# Epoch 21/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3530 - accuracy: 0.8618 - val_loss: 0.3324 - val_accuracy: 0.8662
# Epoch 22/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3553 - accuracy: 0.8500 - val_loss: 0.3399 - val_accuracy: 0.8568
# Epoch 23/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3507 - accuracy: 0.8541 - val_loss: 0.3209 - val_accuracy: 0.8662
# Epoch 24/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3415 - accuracy: 0.8606 - val_loss: 0.3194 - val_accuracy: 0.8662
# Epoch 25/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3430 - accuracy: 0.8553 - val_loss: 0.3321 - val_accuracy: 0.8521
# Epoch 26/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3275 - accuracy: 0.8629 - val_loss: 0.3587 - val_accuracy: 0.8498
# Epoch 27/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3237 - accuracy: 0.8759 - val_loss: 0.3060 - val_accuracy: 0.8709
# Epoch 28/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3117 - accuracy: 0.8747 - val_loss: 0.2930 - val_accuracy: 0.8779
# Epoch 29/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.2984 - accuracy: 0.8835 - val_loss: 0.2813 - val_accuracy: 0.8873
# Epoch 30/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3060 - accuracy: 0.8759 - val_loss: 0.2786 - val_accuracy: 0.8944
# Epoch 31/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.3048 - accuracy: 0.8759 - val_loss: 0.2736 - val_accuracy: 0.8850
# Epoch 32/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.2909 - accuracy: 0.8888 - val_loss: 0.2868 - val_accuracy: 0.8803
# Epoch 33/50
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2847 - accuracy: 0.8941 - val_loss: 0.2615 - val_accuracy: 0.8967
# Epoch 34/50
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2689 - accuracy: 0.9018 - val_loss: 0.2756 - val_accuracy: 0.8991
# Epoch 35/50
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2699 - accuracy: 0.8971 - val_loss: 0.2776 - val_accuracy: 0.9014
# Epoch 36/50
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2654 - accuracy: 0.9094 - val_loss: 0.2537 - val_accuracy: 0.9202
# Epoch 37/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.2633 - accuracy: 0.9035 - val_loss: 0.2723 - val_accuracy: 0.9061
# Epoch 38/50
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2583 - accuracy: 0.9018 - val_loss: 0.2468 - val_accuracy: 0.9085
# Epoch 39/50
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2659 - accuracy: 0.8971 - val_loss: 0.2439 - val_accuracy: 0.9014
# Epoch 40/50
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2642 - accuracy: 0.9035 - val_loss: 0.2452 - val_accuracy: 0.9108
# Epoch 41/50
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2563 - accuracy: 0.9112 - val_loss: 0.2373 - val_accuracy: 0.9155
# Epoch 42/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.2579 - accuracy: 0.9065 - val_loss: 0.2387 - val_accuracy: 0.9108
# Epoch 43/50
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2435 - accuracy: 0.9100 - val_loss: 0.2428 - val_accuracy: 0.9131
# Epoch 44/50
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2477 - accuracy: 0.9176 - val_loss: 0.2327 - val_accuracy: 0.9225
# Epoch 45/50
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2406 - accuracy: 0.9118 - val_loss: 0.2320 - val_accuracy: 0.9108
# Epoch 46/50
# 54/54 [==============================] - 0s 2ms/step - loss: 0.2378 - accuracy: 0.9118 - val_loss: 0.2318 - val_accuracy: 0.9155
# Epoch 47/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.2363 - accuracy: 0.9176 - val_loss: 0.2283 - val_accuracy: 0.9178
# Epoch 48/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.2381 - accuracy: 0.9159 - val_loss: 0.2224 - val_accuracy: 0.9343
# Epoch 49/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.2383 - accuracy: 0.9176 - val_loss: 0.2206 - val_accuracy: 0.9296
# Epoch 50/50
# 54/54 [==============================] - 0s 1ms/step - loss: 0.2310 - accuracy: 0.9165 - val_loss: 0.2213 - val_accuracy: 0.9249
#
#  Training Time: 7.21875
# 17/17 [==============================] - 0s 645us/step - loss: 0.2776 - accuracy: 0.8929
#
#  Testing time: 0.078125
# Test loss: 0.2776224911212921
# Test accuracy:  0.8928571343421936
# Classification_report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90       266
#            1       0.94      0.84      0.89       266
#
#     accuracy                           0.89       532
#    macro avg       0.90      0.89      0.89       532
# weighted avg       0.90      0.89      0.89       532

# %% [markdown]
# __ii) Neural network 2 for Death label__

# %%
# Neural Network 2 for Death label
DNN(XD_sm,YD_OHE)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Layer dense_246 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 50/50 [==============================] - 0s 4ms/step - loss: 1.5960 - accuracy: 0.4887 - val_loss: 0.7267 - val_accuracy: 0.5477
# Epoch 2/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6607 - accuracy: 0.5930 - val_loss: 0.6491 - val_accuracy: 0.6332
# Epoch 3/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6077 - accuracy: 0.6545 - val_loss: 0.6169 - val_accuracy: 0.6407
# Epoch 4/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5813 - accuracy: 0.6671 - val_loss: 0.6071 - val_accuracy: 0.6608
# Epoch 5/50
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5536 - accuracy: 0.7079 - val_loss: 0.5732 - val_accuracy: 0.7010
# Epoch 6/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5368 - accuracy: 0.7173 - val_loss: 0.5660 - val_accuracy: 0.7286
# Epoch 7/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5230 - accuracy: 0.7387 - val_loss: 0.5533 - val_accuracy: 0.7111
# Epoch 8/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5068 - accuracy: 0.7412 - val_loss: 0.5398 - val_accuracy: 0.7437
# Epoch 9/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4974 - accuracy: 0.7651 - val_loss: 0.5277 - val_accuracy: 0.7236
# Epoch 10/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4913 - accuracy: 0.7676 - val_loss: 0.5133 - val_accuracy: 0.7764
# Epoch 11/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4775 - accuracy: 0.7720 - val_loss: 0.5131 - val_accuracy: 0.7613
# Epoch 12/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4739 - accuracy: 0.7770 - val_loss: 0.4970 - val_accuracy: 0.7839
# Epoch 13/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4656 - accuracy: 0.7820 - val_loss: 0.4947 - val_accuracy: 0.7638
# Epoch 14/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4602 - accuracy: 0.7902 - val_loss: 0.4866 - val_accuracy: 0.7839
# Epoch 15/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4597 - accuracy: 0.7751 - val_loss: 0.4831 - val_accuracy: 0.7814
# Epoch 16/50
# 50/50 [==============================] - ETA: 0s - loss: 0.3954 - accuracy: 0.81 - 0s 1ms/step - loss: 0.4488 - accuracy: 0.7883 - val_loss: 0.4740 - val_accuracy: 0.7814
# Epoch 17/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4434 - accuracy: 0.8009 - val_loss: 0.4674 - val_accuracy: 0.8015
# Epoch 18/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4384 - accuracy: 0.8046 - val_loss: 0.4635 - val_accuracy: 0.8015
# Epoch 19/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4377 - accuracy: 0.8103 - val_loss: 0.4587 - val_accuracy: 0.7915
# Epoch 20/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4376 - accuracy: 0.8065 - val_loss: 0.4832 - val_accuracy: 0.7864
# Epoch 21/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4353 - accuracy: 0.8009 - val_loss: 0.4539 - val_accuracy: 0.7889
# Epoch 22/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4315 - accuracy: 0.8053 - val_loss: 0.4468 - val_accuracy: 0.8040
# Epoch 23/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4235 - accuracy: 0.8134 - val_loss: 0.4491 - val_accuracy: 0.7864
# Epoch 24/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4244 - accuracy: 0.8090 - val_loss: 0.4415 - val_accuracy: 0.8015
# Epoch 25/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4177 - accuracy: 0.8153 - val_loss: 0.4451 - val_accuracy: 0.8015
# Epoch 26/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4170 - accuracy: 0.8153 - val_loss: 0.4381 - val_accuracy: 0.7864
# Epoch 27/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4158 - accuracy: 0.8084 - val_loss: 0.4412 - val_accuracy: 0.8090
# Epoch 28/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4072 - accuracy: 0.8172 - val_loss: 0.4350 - val_accuracy: 0.8040
# Epoch 29/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4134 - accuracy: 0.8141 - val_loss: 0.4331 - val_accuracy: 0.7915
# Epoch 30/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4082 - accuracy: 0.8191 - val_loss: 0.4269 - val_accuracy: 0.8015
# Epoch 31/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4104 - accuracy: 0.8078 - val_loss: 0.4545 - val_accuracy: 0.7864
# Epoch 32/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4108 - accuracy: 0.8185 - val_loss: 0.4420 - val_accuracy: 0.7915
# Epoch 33/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4063 - accuracy: 0.8147 - val_loss: 0.4177 - val_accuracy: 0.8090
# Epoch 34/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4066 - accuracy: 0.8229 - val_loss: 0.4265 - val_accuracy: 0.8065
# Epoch 35/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3984 - accuracy: 0.8204 - val_loss: 0.4224 - val_accuracy: 0.8116
# Epoch 36/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3958 - accuracy: 0.8197 - val_loss: 0.4163 - val_accuracy: 0.8040
# Epoch 37/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3911 - accuracy: 0.8222 - val_loss: 0.4370 - val_accuracy: 0.7940
# Epoch 38/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3952 - accuracy: 0.8266 - val_loss: 0.4316 - val_accuracy: 0.8317
# Epoch 39/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4064 - accuracy: 0.8178 - val_loss: 0.4347 - val_accuracy: 0.8090
# Epoch 40/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3925 - accuracy: 0.8279 - val_loss: 0.4114 - val_accuracy: 0.8191
# Epoch 41/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3980 - accuracy: 0.8323 - val_loss: 0.4160 - val_accuracy: 0.8040
# Epoch 42/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3851 - accuracy: 0.8342 - val_loss: 0.4142 - val_accuracy: 0.8241
# Epoch 43/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3901 - accuracy: 0.8304 - val_loss: 0.4925 - val_accuracy: 0.7538
# Epoch 44/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3920 - accuracy: 0.8222 - val_loss: 0.4194 - val_accuracy: 0.7990
# Epoch 45/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3885 - accuracy: 0.8317 - val_loss: 0.4096 - val_accuracy: 0.8116
# Epoch 46/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3783 - accuracy: 0.8392 - val_loss: 0.4212 - val_accuracy: 0.8266
# Epoch 47/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3805 - accuracy: 0.8291 - val_loss: 0.4267 - val_accuracy: 0.8166
# Epoch 48/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3920 - accuracy: 0.8291 - val_loss: 0.4205 - val_accuracy: 0.8266
# Epoch 49/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3750 - accuracy: 0.8373 - val_loss: 0.4009 - val_accuracy: 0.8166
# Epoch 50/50
# 50/50 [==============================] - 0s 1ms/step - loss: 0.3776 - accuracy: 0.8329 - val_loss: 0.4020 - val_accuracy: 0.8241
#
#  Training Time: 6.53125
#  1/16 [>.............................] - ETA: 0s - loss: 0.3713 - accuracy: 0.7812WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 16/16 [==============================] - 0s 686us/step - loss: 0.4233 - accuracy: 0.8072
#
#  Testing time: 0.0625
# Test loss: 0.4232674241065979
# Test accuracy:  0.8072289228439331
# Classification_report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.88      0.82       249
#            1       0.86      0.73      0.79       249
#
#     accuracy                           0.81       498
#    macro avg       0.81      0.81      0.81       498
# weighted avg       0.81      0.81      0.81       498

# %% [markdown]
# __iii) Neural network 3 for Recovered label__

# %%
# Neural Network 3 for Recovered label
DNN(XR_sm,YR_OHE)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Layer dense_249 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 35/35 [==============================] - 0s 5ms/step - loss: 1.0998 - accuracy: 0.5511 - val_loss: 0.7305 - val_accuracy: 0.6498
# Epoch 2/50
# 35/35 [==============================] - 1s 37ms/step - loss: 0.6199 - accuracy: 0.6688 - val_loss: 0.6258 - val_accuracy: 0.6137
# Epoch 3/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.5628 - accuracy: 0.6869 - val_loss: 0.6073 - val_accuracy: 0.6390
# Epoch 4/50
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5634 - accuracy: 0.6932 - val_loss: 0.6520 - val_accuracy: 0.6895
# Epoch 5/50
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5256 - accuracy: 0.7032 - val_loss: 0.5373 - val_accuracy: 0.6895
# Epoch 6/50
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4873 - accuracy: 0.7367 - val_loss: 0.5014 - val_accuracy: 0.7148
# Epoch 7/50
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4632 - accuracy: 0.7873 - val_loss: 0.5279 - val_accuracy: 0.7148
# Epoch 8/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4618 - accuracy: 0.7882 - val_loss: 0.4631 - val_accuracy: 0.8051
# Epoch 9/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4374 - accuracy: 0.8118 - val_loss: 0.4528 - val_accuracy: 0.7726
# Epoch 10/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4223 - accuracy: 0.8208 - val_loss: 0.4434 - val_accuracy: 0.8339
# Epoch 11/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.4179 - accuracy: 0.8308 - val_loss: 0.4319 - val_accuracy: 0.7906
# Epoch 12/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3938 - accuracy: 0.8534 - val_loss: 0.4114 - val_accuracy: 0.8375
# Epoch 13/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3857 - accuracy: 0.8516 - val_loss: 0.4003 - val_accuracy: 0.8412
# Epoch 14/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3764 - accuracy: 0.8462 - val_loss: 0.3959 - val_accuracy: 0.8267
# Epoch 15/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3657 - accuracy: 0.8588 - val_loss: 0.4122 - val_accuracy: 0.8014
# Epoch 16/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3723 - accuracy: 0.8498 - val_loss: 0.3814 - val_accuracy: 0.8231
# Epoch 17/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3536 - accuracy: 0.8561 - val_loss: 0.3666 - val_accuracy: 0.8628
# Epoch 18/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3459 - accuracy: 0.8606 - val_loss: 0.3577 - val_accuracy: 0.8773
# Epoch 19/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3516 - accuracy: 0.8462 - val_loss: 0.3479 - val_accuracy: 0.8736
# Epoch 20/50
# 35/35 [==============================] - 0s 5ms/step - loss: 0.3394 - accuracy: 0.8624 - val_loss: 0.3594 - val_accuracy: 0.8412
# Epoch 21/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3407 - accuracy: 0.8516 - val_loss: 0.3680 - val_accuracy: 0.8303
# Epoch 22/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3327 - accuracy: 0.8552 - val_loss: 0.3413 - val_accuracy: 0.8484
# Epoch 23/50
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3351 - accuracy: 0.8796 - val_loss: 0.3406 - val_accuracy: 0.8448
# Epoch 24/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3260 - accuracy: 0.8706 - val_loss: 0.3426 - val_accuracy: 0.8484
# Epoch 25/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.3100 - accuracy: 0.8833 - val_loss: 0.3158 - val_accuracy: 0.8628
# Epoch 26/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2914 - accuracy: 0.8878 - val_loss: 0.3213 - val_accuracy: 0.8628
# Epoch 27/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2913 - accuracy: 0.8950 - val_loss: 0.3022 - val_accuracy: 0.8845
# Epoch 28/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2878 - accuracy: 0.8995 - val_loss: 0.3107 - val_accuracy: 0.8809
# Epoch 29/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2865 - accuracy: 0.8923 - val_loss: 0.3022 - val_accuracy: 0.8917
# Epoch 30/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2771 - accuracy: 0.9023 - val_loss: 0.2942 - val_accuracy: 0.8917
# Epoch 31/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2712 - accuracy: 0.9041 - val_loss: 0.3015 - val_accuracy: 0.8736
# Epoch 32/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2726 - accuracy: 0.8968 - val_loss: 0.2792 - val_accuracy: 0.8917
# Epoch 33/50
# 35/35 [==============================] - ETA: 0s - loss: 0.2076 - accuracy: 0.90 - 0s 1ms/step - loss: 0.2647 - accuracy: 0.9095 - val_loss: 0.2956 - val_accuracy: 0.8700
# Epoch 34/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2756 - accuracy: 0.8941 - val_loss: 0.2678 - val_accuracy: 0.8881
# Epoch 35/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2549 - accuracy: 0.9167 - val_loss: 0.2757 - val_accuracy: 0.8773
# Epoch 36/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2531 - accuracy: 0.9104 - val_loss: 0.2644 - val_accuracy: 0.8809
# Epoch 37/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2475 - accuracy: 0.9068 - val_loss: 0.2684 - val_accuracy: 0.8809
# Epoch 38/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2579 - accuracy: 0.8995 - val_loss: 0.2745 - val_accuracy: 0.8700
# Epoch 39/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2391 - accuracy: 0.9104 - val_loss: 0.2552 - val_accuracy: 0.8917
# Epoch 40/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2396 - accuracy: 0.9131 - val_loss: 0.2884 - val_accuracy: 0.8664
# Epoch 41/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2514 - accuracy: 0.9104 - val_loss: 0.2492 - val_accuracy: 0.8989
# Epoch 42/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2401 - accuracy: 0.9140 - val_loss: 0.3392 - val_accuracy: 0.8556
# Epoch 43/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2587 - accuracy: 0.9005 - val_loss: 0.2771 - val_accuracy: 0.8881
# Epoch 44/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2410 - accuracy: 0.9158 - val_loss: 0.2456 - val_accuracy: 0.8989
# Epoch 45/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2315 - accuracy: 0.9149 - val_loss: 0.2457 - val_accuracy: 0.8809
# Epoch 46/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2274 - accuracy: 0.9176 - val_loss: 0.2337 - val_accuracy: 0.9097
# Epoch 47/50
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2178 - accuracy: 0.9167 - val_loss: 0.2356 - val_accuracy: 0.9097
# Epoch 48/50
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2182 - accuracy: 0.9303 - val_loss: 0.2345 - val_accuracy: 0.8989
# Epoch 49/50
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2199 - accuracy: 0.9267 - val_loss: 0.2304 - val_accuracy: 0.9242
# Epoch 50/50
# 35/35 [==============================] - 0s 1ms/step - loss: 0.2189 - accuracy: 0.9158 - val_loss: 0.2552 - val_accuracy: 0.8917
#
#  Training Time: 5.1875
#  1/11 [=>............................] - ETA: 0s - loss: 0.3886 - accuracy: 0.7812WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_test_batch_end` time: 0.0010s). Check your callbacks.
# 11/11 [==============================] - 0s 635us/step - loss: 0.2824 - accuracy: 0.8815
#
#  Testing time: 0.0625
# Test loss: 0.2823958694934845
# Test accuracy:  0.8815028667449951
# Classification_report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.80      0.87       173
#            1       0.83      0.96      0.89       173
#
#     accuracy                           0.88       346
#    macro avg       0.89      0.88      0.88       346
# weighted avg       0.89      0.88      0.88       346

# %% [markdown]
# ### B) Training and testing the model for imbalanced dataset

# %% [markdown]
# __i) Neural network 1 for Confirmed label__

# %%
# Neural Network 1 for Confirmed label
YC_im = OHE(YC)
DNN(X,YC_im)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Layer dense_15 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 28/28 [==============================] - 0s 9ms/step - loss: 6.7271 - accuracy: 0.1268 - val_loss: 2.1346 - val_accuracy: 0.3801
# Epoch 2/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.7456 - accuracy: 0.7418 - val_loss: 0.2496 - val_accuracy: 0.9593
# Epoch 3/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2417 - accuracy: 0.9604 - val_loss: 0.2167 - val_accuracy: 0.9638
# Epoch 4/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2223 - accuracy: 0.9626 - val_loss: 0.2084 - val_accuracy: 0.9638
# Epoch 5/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2072 - accuracy: 0.9626 - val_loss: 0.2025 - val_accuracy: 0.9638
# Epoch 6/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1939 - accuracy: 0.9626 - val_loss: 0.1969 - val_accuracy: 0.9638
# Epoch 7/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1827 - accuracy: 0.9626 - val_loss: 0.1861 - val_accuracy: 0.9638
# Epoch 8/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1731 - accuracy: 0.9626 - val_loss: 0.1787 - val_accuracy: 0.9638
# Epoch 9/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1660 - accuracy: 0.9626 - val_loss: 0.1714 - val_accuracy: 0.9638
# Epoch 10/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1596 - accuracy: 0.9626 - val_loss: 0.1652 - val_accuracy: 0.9638
# Epoch 11/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1549 - accuracy: 0.9626 - val_loss: 0.1596 - val_accuracy: 0.9638
# Epoch 12/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1503 - accuracy: 0.9626 - val_loss: 0.1549 - val_accuracy: 0.9638
# Epoch 13/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1471 - accuracy: 0.9626 - val_loss: 0.1501 - val_accuracy: 0.9638
# Epoch 14/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1438 - accuracy: 0.9626 - val_loss: 0.1474 - val_accuracy: 0.9638
# Epoch 15/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1421 - accuracy: 0.9626 - val_loss: 0.1430 - val_accuracy: 0.9638
# Epoch 16/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1404 - accuracy: 0.9626 - val_loss: 0.1410 - val_accuracy: 0.9638
# Epoch 17/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1364 - accuracy: 0.9626 - val_loss: 0.1381 - val_accuracy: 0.9638
# Epoch 18/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1345 - accuracy: 0.9626 - val_loss: 0.1374 - val_accuracy: 0.9638
# Epoch 19/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1338 - accuracy: 0.9626 - val_loss: 0.1356 - val_accuracy: 0.9638
# Epoch 20/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1328 - accuracy: 0.9626 - val_loss: 0.1341 - val_accuracy: 0.9638
# Epoch 21/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1325 - accuracy: 0.9626 - val_loss: 0.1324 - val_accuracy: 0.9638
# Epoch 22/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1336 - accuracy: 0.9626 - val_loss: 0.1327 - val_accuracy: 0.9638
# Epoch 23/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1297 - accuracy: 0.9638 - val_loss: 0.1309 - val_accuracy: 0.9638
# Epoch 24/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1278 - accuracy: 0.9626 - val_loss: 0.1297 - val_accuracy: 0.9638
# Epoch 25/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1294 - accuracy: 0.9604 - val_loss: 0.1306 - val_accuracy: 0.9638
# Epoch 26/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1262 - accuracy: 0.9638 - val_loss: 0.1299 - val_accuracy: 0.9638
# Epoch 27/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1244 - accuracy: 0.9638 - val_loss: 0.1308 - val_accuracy: 0.9638
# Epoch 28/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1266 - accuracy: 0.9638 - val_loss: 0.1276 - val_accuracy: 0.9638
# Epoch 29/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1234 - accuracy: 0.9638 - val_loss: 0.1269 - val_accuracy: 0.9638
# Epoch 30/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1232 - accuracy: 0.9626 - val_loss: 0.1268 - val_accuracy: 0.9638
# Epoch 31/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1241 - accuracy: 0.9626 - val_loss: 0.1283 - val_accuracy: 0.9683
# Epoch 32/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1225 - accuracy: 0.9649 - val_loss: 0.1259 - val_accuracy: 0.9638
# Epoch 33/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1224 - accuracy: 0.9626 - val_loss: 0.1253 - val_accuracy: 0.9638
# Epoch 34/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1220 - accuracy: 0.9615 - val_loss: 0.1252 - val_accuracy: 0.9638
# Epoch 35/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1199 - accuracy: 0.9626 - val_loss: 0.1252 - val_accuracy: 0.9638
# Epoch 36/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1206 - accuracy: 0.9649 - val_loss: 0.1254 - val_accuracy: 0.9638
# Epoch 37/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1200 - accuracy: 0.9626 - val_loss: 0.1247 - val_accuracy: 0.9638
# Epoch 38/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1184 - accuracy: 0.9649 - val_loss: 0.1231 - val_accuracy: 0.9638
# Epoch 39/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1177 - accuracy: 0.9649 - val_loss: 0.1233 - val_accuracy: 0.9638
# Epoch 40/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1176 - accuracy: 0.9626 - val_loss: 0.1241 - val_accuracy: 0.9638
# Epoch 41/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1176 - accuracy: 0.9638 - val_loss: 0.1242 - val_accuracy: 0.9638
# Epoch 42/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1175 - accuracy: 0.9638 - val_loss: 0.1245 - val_accuracy: 0.9638
# Epoch 43/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1174 - accuracy: 0.9626 - val_loss: 0.1249 - val_accuracy: 0.9683
# Epoch 44/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1161 - accuracy: 0.9649 - val_loss: 0.1224 - val_accuracy: 0.9638
# Epoch 45/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1160 - accuracy: 0.9638 - val_loss: 0.1222 - val_accuracy: 0.9638
# Epoch 46/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1159 - accuracy: 0.9660 - val_loss: 0.1236 - val_accuracy: 0.9683
# Epoch 47/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1155 - accuracy: 0.9638 - val_loss: 0.1226 - val_accuracy: 0.9638
# Epoch 48/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1155 - accuracy: 0.9649 - val_loss: 0.1215 - val_accuracy: 0.9683
# Epoch 49/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.1145 - accuracy: 0.9649 - val_loss: 0.1216 - val_accuracy: 0.9638
# Epoch 50/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.1136 - accuracy: 0.9660 - val_loss: 0.1220 - val_accuracy: 0.9683
#
#  Training Time: 4.375
# 9/9 [==============================] - 0s 665us/step - loss: 0.1561 - accuracy: 0.9384
#
#  Testing time: 0.0625
# Test loss: 0.1560717076063156
# Test accuracy:  0.9384058117866516
# Classification_report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        10
#            1       0.96      0.97      0.97       266
#
#     accuracy                           0.94       276
#    macro avg       0.48      0.49      0.48       276
# weighted avg       0.93      0.94      0.93       276

# %% [markdown]
# __ii) Neural network 2 for Death label__

# %%
# Neural Network 2 for Death label
YD_im = OHE(YD)
DNN(X,YD_im)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Layer dense_24 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 28/28 [==============================] - 0s 6ms/step - loss: 0.6894 - accuracy: 0.7735 - val_loss: 0.4212 - val_accuracy: 0.9005
# Epoch 2/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3504 - accuracy: 0.8958 - val_loss: 0.3363 - val_accuracy: 0.9050
# Epoch 3/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3097 - accuracy: 0.8992 - val_loss: 0.3099 - val_accuracy: 0.8959
# Epoch 4/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2932 - accuracy: 0.9003 - val_loss: 0.3069 - val_accuracy: 0.9005
# Epoch 5/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2864 - accuracy: 0.9003 - val_loss: 0.3015 - val_accuracy: 0.9005
# Epoch 6/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2833 - accuracy: 0.8981 - val_loss: 0.2973 - val_accuracy: 0.9005
# Epoch 7/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2764 - accuracy: 0.8981 - val_loss: 0.3021 - val_accuracy: 0.9005
# Epoch 8/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2740 - accuracy: 0.8992 - val_loss: 0.2960 - val_accuracy: 0.8959
# Epoch 9/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2711 - accuracy: 0.9003 - val_loss: 0.2963 - val_accuracy: 0.9005
# Epoch 10/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2691 - accuracy: 0.8992 - val_loss: 0.2954 - val_accuracy: 0.9005
# Epoch 11/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2697 - accuracy: 0.8992 - val_loss: 0.2952 - val_accuracy: 0.9005
# Epoch 12/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2628 - accuracy: 0.9015 - val_loss: 0.2952 - val_accuracy: 0.9005
# Epoch 13/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2595 - accuracy: 0.9003 - val_loss: 0.2976 - val_accuracy: 0.9050
# Epoch 14/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2605 - accuracy: 0.9037 - val_loss: 0.2938 - val_accuracy: 0.9005
# Epoch 15/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2557 - accuracy: 0.9003 - val_loss: 0.2976 - val_accuracy: 0.8959
# Epoch 16/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2581 - accuracy: 0.9049 - val_loss: 0.2926 - val_accuracy: 0.9050
# Epoch 17/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2546 - accuracy: 0.9049 - val_loss: 0.2979 - val_accuracy: 0.9050
# Epoch 18/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2503 - accuracy: 0.9015 - val_loss: 0.2926 - val_accuracy: 0.9005
# Epoch 19/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2476 - accuracy: 0.9049 - val_loss: 0.2942 - val_accuracy: 0.9095
# Epoch 20/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2473 - accuracy: 0.9060 - val_loss: 0.3013 - val_accuracy: 0.9050
# Epoch 21/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2446 - accuracy: 0.9071 - val_loss: 0.2919 - val_accuracy: 0.9050
# Epoch 22/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2453 - accuracy: 0.9105 - val_loss: 0.2897 - val_accuracy: 0.9050
# Epoch 23/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2396 - accuracy: 0.9094 - val_loss: 0.2933 - val_accuracy: 0.9095
# Epoch 24/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2385 - accuracy: 0.9139 - val_loss: 0.2918 - val_accuracy: 0.9005
# Epoch 25/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2384 - accuracy: 0.9071 - val_loss: 0.2928 - val_accuracy: 0.9095
# Epoch 26/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2361 - accuracy: 0.9151 - val_loss: 0.2904 - val_accuracy: 0.9050
# Epoch 27/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2348 - accuracy: 0.9117 - val_loss: 0.2938 - val_accuracy: 0.9095
# Epoch 28/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2310 - accuracy: 0.9151 - val_loss: 0.2944 - val_accuracy: 0.9095
# Epoch 29/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2336 - accuracy: 0.9105 - val_loss: 0.2902 - val_accuracy: 0.9050
# Epoch 30/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2312 - accuracy: 0.9173 - val_loss: 0.2989 - val_accuracy: 0.9050
# Epoch 31/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2277 - accuracy: 0.9128 - val_loss: 0.2976 - val_accuracy: 0.9095
# Epoch 32/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2274 - accuracy: 0.9196 - val_loss: 0.3017 - val_accuracy: 0.9005
# Epoch 33/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2270 - accuracy: 0.9139 - val_loss: 0.2944 - val_accuracy: 0.9140
# Epoch 34/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2250 - accuracy: 0.9139 - val_loss: 0.2986 - val_accuracy: 0.9095
# Epoch 35/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2267 - accuracy: 0.9173 - val_loss: 0.2962 - val_accuracy: 0.9095
# Epoch 36/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2224 - accuracy: 0.9196 - val_loss: 0.2959 - val_accuracy: 0.9095
# Epoch 37/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2227 - accuracy: 0.9151 - val_loss: 0.3061 - val_accuracy: 0.9095
# Epoch 38/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2248 - accuracy: 0.9162 - val_loss: 0.3048 - val_accuracy: 0.9140
# Epoch 39/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2277 - accuracy: 0.9117 - val_loss: 0.2970 - val_accuracy: 0.9095
# Epoch 40/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2225 - accuracy: 0.9139 - val_loss: 0.3086 - val_accuracy: 0.9005
# Epoch 41/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2190 - accuracy: 0.9162 - val_loss: 0.3069 - val_accuracy: 0.9095
# Epoch 42/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2166 - accuracy: 0.9207 - val_loss: 0.3003 - val_accuracy: 0.9095
# Epoch 43/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2159 - accuracy: 0.9151 - val_loss: 0.3057 - val_accuracy: 0.9095
# Epoch 44/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2201 - accuracy: 0.9128 - val_loss: 0.3021 - val_accuracy: 0.9050
# Epoch 45/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2150 - accuracy: 0.9196 - val_loss: 0.3120 - val_accuracy: 0.8959
# Epoch 46/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2238 - accuracy: 0.9151 - val_loss: 0.3218 - val_accuracy: 0.8959
# Epoch 47/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2187 - accuracy: 0.9128 - val_loss: 0.3085 - val_accuracy: 0.9095
# Epoch 48/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.2188 - accuracy: 0.9173 - val_loss: 0.3027 - val_accuracy: 0.9050
# Epoch 49/50
# 28/28 [==============================] - ETA: 0s - loss: 0.3190 - accuracy: 0.84 - 0s 2ms/step - loss: 0.2137 - accuracy: 0.9196 - val_loss: 0.3162 - val_accuracy: 0.9005
# Epoch 50/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.2174 - accuracy: 0.9173 - val_loss: 0.3065 - val_accuracy: 0.9095
#
#  Training Time: 4.171875
# 9/9 [==============================] - 0s 776us/step - loss: 0.3018 - accuracy: 0.9094
#
#  Testing time: 0.0625
# Test loss: 0.3018072247505188
# Test accuracy:  0.9094203114509583
# Classification_report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.19      0.29        27
#            1       0.92      0.99      0.95       249
#
#     accuracy                           0.91       276
#    macro avg       0.77      0.59      0.62       276
# weighted avg       0.89      0.91      0.89       276

# %% [markdown]
# __iii) Neural network 3 for Recovered label__

# %%
# Neural Network 3 for Recovered label
YR_im = OHE(YR)
DNN(X,YR_im)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Layer dense_48 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 28/28 [==============================] - 0s 6ms/step - loss: 1.3039 - accuracy: 0.5311 - val_loss: 0.6165 - val_accuracy: 0.6561
# Epoch 2/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.7070 - accuracy: 0.6467 - val_loss: 0.5637 - val_accuracy: 0.6697
# Epoch 3/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.6002 - accuracy: 0.6478 - val_loss: 0.4905 - val_accuracy: 0.7466
# Epoch 4/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.5598 - accuracy: 0.6840 - val_loss: 0.4805 - val_accuracy: 0.7647
# Epoch 5/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.5383 - accuracy: 0.7169 - val_loss: 0.4768 - val_accuracy: 0.7466
# Epoch 6/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.5257 - accuracy: 0.7293 - val_loss: 0.4563 - val_accuracy: 0.7828
# Epoch 7/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5177 - accuracy: 0.7497 - val_loss: 0.4708 - val_accuracy: 0.7557
# Epoch 8/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.5027 - accuracy: 0.7599 - val_loss: 0.4403 - val_accuracy: 0.8009
# Epoch 9/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4883 - accuracy: 0.7588 - val_loss: 0.4411 - val_accuracy: 0.8145
# Epoch 10/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4787 - accuracy: 0.7746 - val_loss: 0.4209 - val_accuracy: 0.8190
# Epoch 11/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4668 - accuracy: 0.7916 - val_loss: 0.4205 - val_accuracy: 0.8190
# Epoch 12/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4617 - accuracy: 0.7860 - val_loss: 0.4202 - val_accuracy: 0.8326
# Epoch 13/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4513 - accuracy: 0.7984 - val_loss: 0.4029 - val_accuracy: 0.8235
# Epoch 14/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4404 - accuracy: 0.7916 - val_loss: 0.4138 - val_accuracy: 0.8100
# Epoch 15/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4470 - accuracy: 0.7837 - val_loss: 0.4429 - val_accuracy: 0.7828
# Epoch 16/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4434 - accuracy: 0.7792 - val_loss: 0.3968 - val_accuracy: 0.8054
# Epoch 17/50
# 28/28 [==============================] - ETA: 0s - loss: 0.5234 - accuracy: 0.75 - 0s 2ms/step - loss: 0.4217 - accuracy: 0.7995 - val_loss: 0.3940 - val_accuracy: 0.8145
# Epoch 18/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4171 - accuracy: 0.8063 - val_loss: 0.4086 - val_accuracy: 0.8009
# Epoch 19/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.4215 - accuracy: 0.8120 - val_loss: 0.3846 - val_accuracy: 0.8462
# Epoch 20/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.8165 - val_loss: 0.3787 - val_accuracy: 0.8190
# Epoch 21/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.4001 - accuracy: 0.8165 - val_loss: 0.3671 - val_accuracy: 0.8190
# Epoch 22/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3922 - accuracy: 0.8097 - val_loss: 0.3606 - val_accuracy: 0.8235
# Epoch 23/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3861 - accuracy: 0.8199 - val_loss: 0.3620 - val_accuracy: 0.8235
# Epoch 24/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3902 - accuracy: 0.8222 - val_loss: 0.3625 - val_accuracy: 0.8100
# Epoch 25/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3837 - accuracy: 0.8052 - val_loss: 0.3759 - val_accuracy: 0.8100
# Epoch 26/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3772 - accuracy: 0.8097 - val_loss: 0.3671 - val_accuracy: 0.8145
# Epoch 27/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3732 - accuracy: 0.8279 - val_loss: 0.3419 - val_accuracy: 0.8326
# Epoch 28/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3718 - accuracy: 0.8245 - val_loss: 0.3603 - val_accuracy: 0.8145
# Epoch 29/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3676 - accuracy: 0.8245 - val_loss: 0.3579 - val_accuracy: 0.8190
# Epoch 30/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3670 - accuracy: 0.8109 - val_loss: 0.3418 - val_accuracy: 0.8462
# Epoch 31/50
# 28/28 [==============================] - 0s 2ms/step - loss: 0.3636 - accuracy: 0.8290 - val_loss: 0.3302 - val_accuracy: 0.8326
# Epoch 32/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3574 - accuracy: 0.8335 - val_loss: 0.3400 - val_accuracy: 0.8326
# Epoch 33/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3596 - accuracy: 0.8279 - val_loss: 0.3315 - val_accuracy: 0.8371
# Epoch 34/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3458 - accuracy: 0.8426 - val_loss: 0.3225 - val_accuracy: 0.8281
# Epoch 35/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3417 - accuracy: 0.8233 - val_loss: 0.3160 - val_accuracy: 0.8281
# Epoch 36/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3424 - accuracy: 0.8369 - val_loss: 0.3234 - val_accuracy: 0.8326
# Epoch 37/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3453 - accuracy: 0.8267 - val_loss: 0.3329 - val_accuracy: 0.8778
# Epoch 38/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3471 - accuracy: 0.8482 - val_loss: 0.3073 - val_accuracy: 0.8371
# Epoch 39/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3373 - accuracy: 0.8381 - val_loss: 0.3499 - val_accuracy: 0.8190
# Epoch 40/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3334 - accuracy: 0.8392 - val_loss: 0.3137 - val_accuracy: 0.8371
# Epoch 41/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3322 - accuracy: 0.8516 - val_loss: 0.3087 - val_accuracy: 0.8597
# Epoch 42/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3287 - accuracy: 0.8460 - val_loss: 0.3003 - val_accuracy: 0.8416
# Epoch 43/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3208 - accuracy: 0.8505 - val_loss: 0.3148 - val_accuracy: 0.8688
# Epoch 44/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3170 - accuracy: 0.8505 - val_loss: 0.2949 - val_accuracy: 0.8371
# Epoch 45/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3119 - accuracy: 0.8539 - val_loss: 0.2969 - val_accuracy: 0.8416
# Epoch 46/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3085 - accuracy: 0.8584 - val_loss: 0.2936 - val_accuracy: 0.8643
# Epoch 47/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3123 - accuracy: 0.8516 - val_loss: 0.2926 - val_accuracy: 0.8643
# Epoch 48/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3109 - accuracy: 0.8573 - val_loss: 0.3575 - val_accuracy: 0.8824
# Epoch 49/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3100 - accuracy: 0.8528 - val_loss: 0.2976 - val_accuracy: 0.8507
# Epoch 50/50
# 28/28 [==============================] - 0s 1ms/step - loss: 0.3041 - accuracy: 0.8584 - val_loss: 0.3056 - val_accuracy: 0.8507
#
#  Training Time: 4.15625
# 9/9 [==============================] - 0s 776us/step - loss: 0.3524 - accuracy: 0.8478
#
#  Testing time: 0.0625
# Test loss: 0.35237568616867065
# Test accuracy:  0.8478260636329651
# Classification_report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.69      0.77       103
#            1       0.84      0.94      0.89       173
#
#     accuracy                           0.85       276
#    macro avg       0.86      0.82      0.83       276
# weighted avg       0.85      0.85      0.84       276
